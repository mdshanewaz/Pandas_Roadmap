# %%
import pandas as pd

# %%
df = pd.read_csv('../DATA/survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('../DATA/survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head(3)
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                                Remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                              CodingActivities  \
# ResponseId
# 1                                                         NaN
# 2           Hobby;Contribute to open-source projects;Boots...
# 3           Hobby;Professional development or self-paced l...
#
#                                                  EdLevel  \
# ResponseId
# ...

# %%
high_salary = (df['CompTotal'] > 70000)

# %%
df.loc[high_salary, ['Age', 'EdLevel', 'LanguageHaveWorkedWith', 'CompTotal', 'Country']]
# Out:
#                         Age  \
# ResponseId
# 2           25-34 years old
# 3           45-54 years old
# 4           25-34 years old
# 5           25-34 years old
# 6           35-44 years old
# ...                     ...
# 89176       25-34 years old
# 89178       35-44 years old
# 89179       45-54 years old
# 89180       25-34 years old
# 89184       35-44 years old
#
#                                                       EdLevel  \
# ResponseId
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 6           Some college/university study without earning ...
# ...                                                       ...
# 89176            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 89178         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
countries = ['Turkey', 'Qatar', 'Pakistan', 'Malaysia']
flt_cntry = df['Country'].isin(countries)

# %%
df.loc[flt_cntry, ['Country', 'LanguageHaveWorkedWith']]
# Out:
#              Country                             LanguageHaveWorkedWith
# ResponseId
# 80          Pakistan                                                  C
# 90            Turkey                                                NaN
# 121           Turkey                                      C#;JavaScript
# 135           Turkey   Bash/Shell (all shells);C;C#;C++;HTML/CSS;Python
# 209           Turkey                          JavaScript;Python;R;Swift
# ...              ...                                                ...
# 89076         Turkey                       C#;JavaScript;SQL;TypeScript
# 89096       Pakistan            Dart;HTML/CSS;JavaScript;SQL;TypeScript
# 89112         Turkey           Bash/Shell (all shells);Dart;Java;Kotlin
# 89152       Pakistan  Assembly;C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 89175       Pakistan  Bash/Shell (all shells);C;C++;HTML/CSS;JavaScr...
#
# [1757 rows x 2 columns]

# %%
lang = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
lang
# Out:
# ResponseId
# 1        False
# 2         True
# 3        False
# 4        False
# 5        False
#          ...
# 89180    False
# 89181     True
# 89182     True
# 89183     True
# 89184    False
# Name: LanguageHaveWorkedWith, Length: 89184, dtype: bool

# %%
df.loc[lang]
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 2           I agree  I am a developer by profession     25-34 years old
# 8           I agree  I am a developer by profession     25-34 years old
# 10          I agree  I am a developer by profession     25-34 years old
# 11          I agree  I am a developer by profession     25-34 years old
# 12          I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89173       I agree  I am a developer by profession     45-54 years old
# 89177       I agree  I am a developer by profession     18-24 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
#
#                                         Employment  \
# ResponseId
# ...

# %%
df.loc[lang, 'LanguageHaveWorkedWith']
# Out:
# ResponseId
# 2                               HTML/CSS;JavaScript;Python
# 8        Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 10          HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 11                       C#;C++;HTML/CSS;JavaScript;Python
# 12       C#;HTML/CSS;JavaScript;Kotlin;PowerShell;Pytho...
#                                ...
# 89173    Bash/Shell (all shells);HTML/CSS;JavaScript;Pe...
# 89177    HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeSc...
# 89181                                 Dart;Java;Python;SQL
# 89182    Assembly;Bash/Shell (all shells);C;C#;Python;R...
# 89183    Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# Name: LanguageHaveWorkedWith, Length: 43158, dtype: object
