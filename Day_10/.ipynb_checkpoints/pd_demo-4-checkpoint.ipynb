# %%
import pandas as pd

# %%
df = pd.read_csv('../DATA/survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('../DATA/survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head(5)
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
 df.sort_values(by=['Country', 'CompTotal'], ascending=[True, False], inplace=True)

# %%
df[['Country', 'CompTotal']].head(10)
# Out:
#                 Country    CompTotal
# ResponseId
# 88348       Afghanistan  932464379.0
# 1335        Afghanistan     210000.0
# 57362       Afghanistan     200000.0
# 17873       Afghanistan     100000.0
# 36049       Afghanistan      80000.0
# 53322       Afghanistan      69420.0
# 86039       Afghanistan      68000.0
# 41679       Afghanistan      56666.0
# 39427       Afghanistan       4200.0
# 37956       Afghanistan       3600.0

# %%
df['CompTotal'].nlargest(20)
# Out:
# ResponseId
# 56323    5.000000e+46
# 18464    1.000000e+21
# 43557    1.000000e+16
# 49554    1.000000e+16
# 35780    1.000000e+15
# 15440    4.567887e+12
# 33079    1.000000e+11
# 19680    2.239672e+10
# 56854    1.980000e+10
# 9176     1.840199e+10
# 75524    1.600000e+10
# 33582    1.200000e+10
# 50306    1.000000e+10
# 11113    1.000000e+10
# 39448    1.000000e+10
# 76350    1.000000e+10
# 86198    1.000000e+10
# 32654    9.504000e+09
# 52952    9.374276e+09
# 15398    9.149086e+09
# Name: CompTotal, dtype: float64

# %%
df.nlargest(10, 'CompTotal')
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 56323       I agree                     I am a developer by profession
# 18464       I agree                     I am a developer by profession
# 43557       I agree                     I am a developer by profession
# 49554       I agree  I am not primarily a developer, but I write co...
# 35780       I agree                     I am a developer by profession
# 15440       I agree                     I am a developer by profession
# 33079       I agree                     I am a developer by profession
# 19680       I agree                     I am a developer by profession
# 56854       I agree  I am not primarily a developer, but I write co...
# 9176        I agree                     I am a developer by profession
#
#                         Age  \
# ResponseId
# 56323       25-34 years old
# 18464       25-34 years old
# 43557       18-24 years old
# 49554       25-34 years old
# ...

# %%
df['CompTotal'].median()
# Out:
# 115000.0

# %%
df.describe()
# Out:
#           CompTotal       WorkExp  ConvertedCompYearly
# count  4.822500e+04  43579.000000         4.801900e+04
# mean   1.036807e+42     11.405126         1.031101e+05
# std    2.276847e+44      9.051989         6.814188e+05
# min    0.000000e+00      0.000000         1.000000e+00
# 25%    6.300000e+04      5.000000         4.390700e+04
# 50%    1.150000e+05      9.000000         7.496300e+04
# 75%    2.300000e+05     16.000000         1.216410e+05
# max    5.000000e+46     50.000000         7.435143e+07

# %%
df['CompTotal'].count()
# Out:
# 48225

# %%
df['AIToolInterested in Using']
# Out:
# ResponseId
# 88348                                                  NaN
# 1335                                                   NaN
# 57362                                                  NaN
# 17873                                                  NaN
# 36049    Learning about a codebase;Project planning;Wri...
#                                ...
# 88821                                                  NaN
# 88829                                                  NaN
# 88831                                                  NaN
# 89029                                                  NaN
# 89160                                                  NaN
# Name: AIToolInterested in Using, Length: 89184, dtype: object

# %%
df['AIToolInterested in Using'].value_counts()
# Out:
# AIToolInterested in Using
# Learning about a codebase;Project planning;Writing code;Documenting code;Debugging and getting help;Testing code;Committing and reviewing code;Deployment and monitoring;Collaborating with teammates     1252
# Learning about a codebase;Project planning;Documenting code;Debugging and getting help;Testing code;Committing and reviewing code;Deployment and monitoring;Collaborating with teammates                   742
# Learning about a codebase                                                                                                                                                                                  624
# Documenting code                                                                                                                                                                                           610
# ...

# %%
 df.columns
# Out:
# Index(['Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
# ...

# %%
df['Employment'].value_counts()
# Out:
# Employment
# Employed, full-time                                                                                                                                                                                             53748
# Student, full-time                                                                                                                                                                                               7430
# Independent contractor, freelancer, or self-employed                                                                                                                                                             7076
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                                                                                                         4354
# ...

# %%
df['Employment'].value_counts(normalize=True)
# Out:
# Employment
# Employed, full-time                                                                                                                                                                                             0.611481
# Student, full-time                                                                                                                                                                                              0.084530
# Independent contractor, freelancer, or self-employed                                                                                                                                                            0.080502
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                                                                                                        0.049535
# ...

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Grenada                                                     1
# Guinea-Bissau                                               1
# Liechtenstein                                               1
# Marshall Islands                                            1
# Saint Kitts and Nevis                                       1
# Name: count, Length: 185, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group(('Germany',))
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 14592       I agree                     I am a developer by profession
# 42983       I agree                     I am a developer by profession
# 67542       I agree                     I am a developer by profession
# 19091       I agree                     I am a developer by profession
# 16771       I agree                     I am a developer by profession
# ...             ...                                                ...
# 89038       I agree                        I code primarily as a hobby
# 89065       I agree  I used to be a developer by profession, but no...
# 89108       I agree                     I am a developer by profession
# 89126       I agree                     I am a developer by profession
# 89133       I agree                     I am a developer by profession
#
#                            Age  \
# ResponseId
# 14592          35-44 years old
# ...

# %%
filt = df['Country'] == 'Germany'
df.loc[filt]
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 14592       I agree                     I am a developer by profession
# 42983       I agree                     I am a developer by profession
# 67542       I agree                     I am a developer by profession
# 19091       I agree                     I am a developer by profession
# 16771       I agree                     I am a developer by profession
# ...             ...                                                ...
# 89038       I agree                        I code primarily as a hobby
# 89065       I agree  I used to be a developer by profession, but no...
# 89108       I agree                     I am a developer by profession
# 89126       I agree                     I am a developer by profession
# 89133       I agree                     I am a developer by profession
#
#                            Age  \
# ResponseId
# 14592          35-44 years old
# ...

# %%
filt = df['Country'] == 'Germany'
df.loc[filt]['Employment'].value_counts()
# Out:
# Employment
# Employed, full-time                                                                                                               4347
# Student, full-time                                                                                                                 730
# Independent contractor, freelancer, or self-employed                                                                               498
# Student, full-time;Employed, part-time                                                                                             295
# Employed, part-time                                                                                                                294
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                           259
# Employed, part-time;Student, part-time                                                                                             170
# ...

# %%
country_grp['Employment'].value_counts()
# Out:
# Country      Employment
# Afghanistan  Employed, full-time                                                                                           22
#              Independent contractor, freelancer, or self-employed                                                           8
#              I prefer not to say                                                                                            5
#              Not employed, but looking for work                                                                             5
#              Employed, full-time;Independent contractor, freelancer, or self-employed                                       4
#                                                                                                                            ..
# Zimbabwe     Independent contractor, freelancer, or self-employed;Not employed, but looking for work;Student, full-time     1
# ...

# %%
country_grp['Employment'].value_counts().head(50)
# Out:
# Country      Employment
# Afghanistan  Employed, full-time                                                                                                                                                                                             22
#              Independent contractor, freelancer, or self-employed                                                                                                                                                             8
#              I prefer not to say                                                                                                                                                                                              5
#              Not employed, but looking for work                                                                                                                                                                               5
# ...

# %%
country_grp['Employment'].value_counts().loc['China']
# Out:
# Employment
# Employed, full-time                                                                             372
# Student, full-time                                                                              142
# Independent contractor, freelancer, or self-employed                                             39
# Not employed, but looking for work                                                               28
# Employed, part-time                                                                              11
# Not employed, and not looking for work                                                           10
# Student, part-time                                                                               10
# Employed, full-time;Independent contractor, freelancer, or self-employed                          8
# Employed, full-time;Employed, part-time                                                           6
# ...

# %%
country_grp['CompTotal'].median()
# Out:
# Country
# Afghanistan                                 62333.0
# Albania                                    104850.0
# Algeria                                    540000.0
# Andorra                                    120000.0
# Angola                                    2600000.0
#                                            ...
# Venezuela, Bolivarian Republic of...        14400.0
# Viet Nam                                200000000.0
# Yemen                                        9000.0
# Zambia                                      84000.0
# Zimbabwe                                    12500.0
# Name: CompTotal, Length: 185, dtype: float64

# %%
country_grp['CompTotal'].median().loc['Germany']
# Out:
# 70000.0
