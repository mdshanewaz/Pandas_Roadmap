# %%
import pandas as pd

# %%
people = {
    'first' : ['Shah', 'Shah', 'Kawser'],
    'last' : ['Newaz', 'Waliullah', 'Rana'],
    'email' : ['demo1@mail.com', 'demo2@mail.com', 'demo3@mail.com'],
    'age' : [23, 34, 45]
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#   First_Name  Last_Name           Email  age
# 0       Shah      Newaz  demo1@mail.com   23
# 1       Shah  Waliullah  demo2@mail.com   34
# 2     Kawser       Rana  demo3@mail.com   45

# %%
df['First_Name'] + ' ' + df['Last_Name']
# Out:
# 0        Shah Newaz
# 1    Shah Waliullah
# 2       Kawser Rana
# dtype: object

# %%
df['Full_Name'] = df['First_Name'] + ' ' + df['Last_Name']

# %%
df
# Out:
#   First_Name  Last_Name           Email  age       Full_Name
# 0       Shah      Newaz  demo1@mail.com   23      Shah Newaz
# 1       Shah  Waliullah  demo2@mail.com   34  Shah Waliullah
# 2     Kawser       Rana  demo3@mail.com   45     Kawser Rana

# %%
df.drop(columns = ['First_Name', 'Last_Name'], inplace=True)

# %%
df
# Out:
#             Email  age       Full_Name
# 0  demo1@mail.com   23      Shah Newaz
# 1  demo2@mail.com   34  Shah Waliullah
# 2  demo3@mail.com   45     Kawser Rana

# %%
df['Full_Name'].str.split(' ', expand=True)
# Out:
#         0          1
# 0    Shah      Newaz
# 1    Shah  Waliullah
# 2  Kawser       Rana

# %%
df[['first', 'last']] = df['Full_Name'].str.split(' ', expand=True)

# %%
df
# Out:
#             Email  age       Full_Name   first       last
# 0  demo1@mail.com   23      Shah Newaz    Shah      Newaz
# 1  demo2@mail.com   34  Shah Waliullah    Shah  Waliullah
# 2  demo3@mail.com   45     Kawser Rana  Kawser       Rana

# %%
df._append([{'first': 'Sadman'}])
# Out:
#             Email   age       Full_Name   first       last
# 0  demo1@mail.com  23.0      Shah Newaz    Shah      Newaz
# 1  demo2@mail.com  34.0  Shah Waliullah    Shah  Waliullah
# 2  demo3@mail.com  45.0     Kawser Rana  Kawser       Rana
# 0             NaN   NaN             NaN  Sadman        NaN

# %%
df
# Out:
#             Email  age       Full_Name   first       last
# 0  demo1@mail.com   23      Shah Newaz    Shah      Newaz
# 1  demo2@mail.com   34  Shah Waliullah    Shah  Waliullah
# 2  demo3@mail.com   45     Kawser Rana  Kawser       Rana

# %%
new_row = {'Email': '', 'Full_Name': 'Akib Sadman', 'first': '', 'last': ''}

# %%
new_row_df = pd.DataFrame([new_row])

# %%
df = pd.concat([df, new_row_df])

# %%
df
# Out:
#             Email   age       Full_Name   first       last    Full_name
# 0  demo1@mail.com  23.0      Shah Newaz    Shah      Newaz          NaN
# 1  demo2@mail.com  34.0  Shah Waliullah    Shah  Waliullah          NaN
# 2  demo3@mail.com  45.0     Kawser Rana  Kawser       Rana          NaN
# 0                  28.0             NaN                     Akib Sadman
# 0                  28.0     Akib Sadman                             NaN
# 0                   NaN     Akib Sadman                             NaN

# %%
df.drop(columns = ['Full_name'], inplace=True)

# %%
df
# Out:
#             Email   age       Full_Name   first       last
# 0  demo1@mail.com  23.0      Shah Newaz    Shah      Newaz
# 1  demo2@mail.com  34.0  Shah Waliullah    Shah  Waliullah
# 2  demo3@mail.com  45.0     Kawser Rana  Kawser       Rana
# 0                  28.0             NaN
# 0                  28.0     Akib Sadman
# 0                   NaN     Akib Sadman

# %%
people = {
    'first' : ['Tony', 'James'],
    'last' : ['Stark', 'Bond'],
    'email' : ['demo1@gmail.com', 'demo2@gmail.com']
}

# %%
df_2 = pd.DataFrame(people)

# %%
df_2
# Out:
#    first   last            email
# 0   Tony  Stark  demo1@gmail.com
# 1  James   Bond  demo2@gmail.com

# %%
df._append(df_2)
# Out:
#             Email   age       Full_Name   first       last            email
# 0  demo1@mail.com  23.0      Shah Newaz    Shah      Newaz              NaN
# 1  demo2@mail.com  34.0  Shah Waliullah    Shah  Waliullah              NaN
# 2  demo3@mail.com  45.0     Kawser Rana  Kawser       Rana              NaN
# 0                  28.0             NaN                                 NaN
# 0                  28.0     Akib Sadman                                 NaN
# 0                   NaN     Akib Sadman                                 NaN
# 0             NaN   NaN             NaN    Tony      Stark  demo1@gmail.com
# 1             NaN   NaN             NaN   James       Bond  demo2@gmail.com

# %%
df
# Out:
#             Email   age       Full_Name   first       last
# 0  demo1@mail.com  23.0      Shah Newaz    Shah      Newaz
# 1  demo2@mail.com  34.0  Shah Waliullah    Shah  Waliullah
# 2  demo3@mail.com  45.0     Kawser Rana  Kawser       Rana
# 0                  28.0             NaN
# 0                  28.0     Akib Sadman
# 0                   NaN     Akib Sadman

# %%
df = df._append(df_2)

# %%
df
# Out:
#             Email   age       Full_Name   first       last            email
# 0  demo1@mail.com  23.0      Shah Newaz    Shah      Newaz              NaN
# 1  demo2@mail.com  34.0  Shah Waliullah    Shah  Waliullah              NaN
# 2  demo3@mail.com  45.0     Kawser Rana  Kawser       Rana              NaN
# 0                  28.0             NaN                                 NaN
# 0                  28.0     Akib Sadman                                 NaN
# 0                   NaN     Akib Sadman                                 NaN
# 0             NaN   NaN             NaN    Tony      Stark  demo1@gmail.com
# 1             NaN   NaN             NaN   James       Bond  demo2@gmail.com

# %%
df
# Out:
#             Email   age       Full_Name   first       last            email
# 0  demo1@mail.com  23.0      Shah Newaz    Shah      Newaz              NaN
# 1  demo2@mail.com  34.0  Shah Waliullah    Shah  Waliullah              NaN
# 2  demo3@mail.com  45.0     Kawser Rana  Kawser       Rana              NaN
# 0                  28.0             NaN                                 NaN
# 0                  28.0     Akib Sadman                                 NaN
# 0                   NaN     Akib Sadman                                 NaN
# 0             NaN   NaN             NaN    Tony      Stark  demo1@gmail.com
# 1             NaN   NaN             NaN   James       Bond  demo2@gmail.com

# %%
df.drop(index=0)
# Out:
#             Email   age       Full_Name   first       last            email
# 1  demo2@mail.com  34.0  Shah Waliullah    Shah  Waliullah              NaN
# 2  demo3@mail.com  45.0     Kawser Rana  Kawser       Rana              NaN
# 1             NaN   NaN             NaN   James       Bond  demo2@gmail.com

# %%
df
# Out:
#             Email   age       Full_Name   first       last            email
# 0  demo1@mail.com  23.0      Shah Newaz    Shah      Newaz              NaN
# 1  demo2@mail.com  34.0  Shah Waliullah    Shah  Waliullah              NaN
# 2  demo3@mail.com  45.0     Kawser Rana  Kawser       Rana              NaN
# 0                  28.0             NaN                                 NaN
# 0                  28.0     Akib Sadman                                 NaN
# 0                   NaN     Akib Sadman                                 NaN
# 0             NaN   NaN             NaN    Tony      Stark  demo1@gmail.com
# 1             NaN   NaN             NaN   James       Bond  demo2@gmail.com

# %%
filt =  df['last'] == 'Rana'
df.drop(index=df[filt].index)
# Out:
#             Email   age       Full_Name  first       last            email
# 0  demo1@mail.com  23.0      Shah Newaz   Shah      Newaz              NaN
# 1  demo2@mail.com  34.0  Shah Waliullah   Shah  Waliullah              NaN
# 0                  28.0             NaN                                NaN
# 0                  28.0     Akib Sadman                                NaN
# 0                   NaN     Akib Sadman                                NaN
# 0             NaN   NaN             NaN   Tony      Stark  demo1@gmail.com
# 1             NaN   NaN             NaN  James       Bond  demo2@gmail.com
